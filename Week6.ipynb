# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import metrics
from yellowbrick.cluster import KElbowVisualizer

# Load the Diabetes dataset
df = pd.read_csv('diabetesN.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
df.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# ...

# %%
xx = df.loc[:, ['Glucose', 'BMI']]
xx.head()
# Out:
#    Glucose   BMI
# 0      148  33.6
# 1       85  26.6
# 2      183  23.3
# 3       89  28.1
# 4      137  43.1

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,12))
visualizer.fit(xx)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', random_state=42)
kmeans.fit(xx)
df['Cluster'] = kmeans.labels_
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  Cluster
# 0                     0.627   50        1        0
# 1                     0.351   31        0        2
# 2                     0.672   32        1        1
# 3                     0.167   21        0        2
# 4                     2.288   33        1        0

# %%
clusters = kmeans.labels_.tolist()
silhouette = metrics.silhouette_score(xx, clusters, metric='euclidean')
print("Silhouette Score:", silhouette)
# Out:
# Silhouette Score: 0.45810472456278345

# %%
sns.scatterplot(data=xx, x='Glucose', y='BMI', hue=kmeans.labels_, palette='Set2')
plt.title('K-Means Clustering on Diabetes Data')
plt.xlabel('Glucose Level')
plt.ylabel('BMI')
plt.show()

# %%
new_patients = [[120, 25.0], [160, 35.0], [95, 28.0], [180, 45.0]]
d = pd.DataFrame(new_patients, columns=['Glucose', 'BMI'])
predicted_clusters = kmeans.predict(d)
print(d)
print(predicted_clusters)
# Out:
#    Glucose   BMI
# 0      120  25.0
# 1      160  35.0
# 2       95  28.0
# 3      180  45.0
# [0 1 2 1]
